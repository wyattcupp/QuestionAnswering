# %% [markdown]
# # Question Answering Using the SQuAD v2.0 Dataset
# ### Wyatt Cupp
# #### wyattcupp@gmail.com

# %%
# %pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.5.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers) (3.10.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.10.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers) (0.0.45)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers) (20.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.7.4.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers) (2.4.7)

# %%
import numpy as np
import pandas as pd
import nltk

import os

import json

# %% [markdown]
# ### Loading SQuAD v2.0

# %%
# load the train set
with open('train-v2.0.json') as data_file:
    train_json = json.load(data_file)
    
train_json['data'][0]['paragraphs'][0]['context'] #examine frist context for an example
# Out:
# 'Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Born and raised in Houston, Texas, she performed in various singing and dancing competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny\'s Child. Managed by her father, Mathew Knowles, the group became one of the world\'s best-selling girl groups of all time. Their hiatus saw the release of Beyoncé\'s debut album, Dangerously in Love (2003), which established her as a solo artist worldwide, earned five Grammy Awards and featured the Billboard Hot 100 number-one singles "Crazy in Love" and "Baby Boy".'

# %%
# load the test set
with open('dev-v2.0.json') as f:
    test_json = json.load(f)

# %% [markdown]
# ### Preprocessing SQuAD v2.0
#
# In this section, I will dive into the SQuAD dataset, explore the data, and perform preprocessing on the data.

# %%
import transformers
from transformers import BertTokenizer, BertModel, BertForQuestionAnswering

from tqdm import tqdm

import torch
from torch import cuda
device = 'cuda' if cuda.is_available() else 'cpu' # if CPU, try Google Colab

device
# Out:
# 'cuda'

# %% [markdown]
# The tokenizer we will use is the `BertTokenizer`. This tokenizer is used across a variety of premade BERT models.

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=231508.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=28.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=466062.0, style=ProgressStyle(descripti…

# %%
def char_index_mapper(context, context_tokenized):
    """
    Maps from a start str index, to a tokenized index within a list of tokens.
    """
    # map from a start index in a str, to a tokenized index in token list
    mapper = {}
    curr = ''
    token_idx = 0
    for i, char in enumerate(context):
        if char != ' ' and char != '\n' and char != '\t' and char != '\r': # make sure current char is not whitespace
            curr += char
            if curr == context_tokenized[token_idx]:
                start = i - len(curr) + 1
                for j in range(start, i+1):
                    mapper[j] = (curr, token_idx)                
                curr = ''
                token_idx += 1
    if token_idx != len(context_tokenized): # problems with doc span within the data, skip example.
        return None
            
    return mapper
            
def preprocess_data(dataset, is_training=True, tokenized=False):
    """
    Parse the json_data object into a pandas readable data representation (list of dicts)
    
    Params:
        dataset -- JSON dataset object
        tokenized -- Boolean representing whether to tokenize context & question or not (default False)
    Returns:
        examples -- list of dicts representing SQuAD dataset
    """
    
    def _tokenize(seq):
        """
        Minimizes errors between tokenizers and encodings.
        Recommended in the paper BiDAF (Seo et al., 2016)
        """
        return [t.replace("``", '"').replace("''", '"') for t in seq.split()]
    
    examples = [] # store rows of data here for qa
    
    tokenization_errors = 0
    misaligned_ans_errors = 0
    num_impossibles = 0
    num_questions = 0
    
    for article_id in tqdm(range(len(dataset['data']))): # for each context
        paragraphs = dataset['data'][article_id]['paragraphs']
        for paragraph_id in range(len(paragraphs)):
            questions = dataset['data'][article_id]['paragraphs'][paragraph_id]['qas']
            
            context = paragraphs[paragraph_id]['context']
            context_tokenized = _tokenize(context)
                    
            for qid in range(len(questions)): # loop through questions
                num_questions += 1
                
                question = questions[qid]['question']
                question_tokenized = _tokenize(question)
                qas_id = questions[qid]['id']
                
                is_impossible = questions[qid]['is_impossible']
                
                if is_impossible: # check if question is impossible to answer
                    num_impossibles += 1
                    examples.append({'qas_id': qas_id, 
                                     'question':question_tokenized if tokenized else question, 
                                     'context': context_tokenized if tokenized else context, 
                                     'answer':'', 
                                     'is_impossible': is_impossible,
                                     'start_pos': -1, 
                                     'end_pos':-1,
                                    'santiy_check': context_tokenized[-1:0]})
                    continue
                    
                # question is not impossible, continue parsing
                answers = questions[qid]['answers']
                
                for ans_id in range(len(answers)): # for each answer
                    answer = answers[ans_id]['text']
                    start_pos = answers[ans_id]['answer_start'] # inclusive start index in raw context
                    end_pos = start_pos + len(answer) #exclusive end index in raw context
                          
                    if context[start_pos:end_pos] != answer:
                        misaligned_ans_errors += 1
                        continue
                        
                    if tokenized:
                        mapper = char_index_mapper(context, context_tokenized)
                        if mapper is None:
                            tokenization_errors += 1
                            continue
                        
                        start_pos = mapper[start_pos][1]
                        end_pos = mapper[end_pos-1][1] # inclusive
                    
                    examples.append({'qas_id': qas_id, 
                                     'question':question_tokenized if tokenized else question, 
                                     'context': context_tokenized if tokenized else context, 
                                     'answer':answer, 
                                     'is_impossible': is_impossible,
                                     'start_pos': start_pos, 
                                     'end_pos':end_pos,
                                    'santiy_check': context_tokenized[start_pos:end_pos+1] if tokenized else context[start_pos:end_pos+1]})
            
                    
    print('Total number of questions:{}'.format(num_questions))
    print('Total number of impossible questions:{}'.format(num_impossibles))
    print('Number of tokenization errors:{}'.format(tokenization_errors))
    print('Number of misaligned answer errors:{}'.format(misaligned_ans_errors))
    return examples

# %% [markdown]
# Create the training examples:

# %%
training_examples = preprocess_data(train_json, tokenized=True)
# Out:
# 100%|██████████| 442/442 [00:28<00:00, 15.29it/s]
# Total number of questions:130319
# Total number of impossible questions:43498
# Number of tokenization errors:102
# Number of misaligned answer errors:0

# %% [markdown]
# Now we convert to pandas dataframe to get a better look at the data:

# %%
df = pd.DataFrame(training_examples)
df[df.start_pos == df.end_pos][:40]
# Out:
#                        qas_id  ...         santiy_check
# 2    56be85543aeaaa14008c9066  ...            [(2003),]
# 11   56d43c5f2ccc5a1400d830ac  ...            [(2003),]
# 12   56d43c5f2ccc5a1400d830ad  ...               [five]
# 15   56be86cf3aeaaa14008c9076  ...            [acting,]
# 17   56be86cf3aeaaa14008c9079  ...                [six]
# 18   56bf6e823aeaaa14008c9627  ...         [Dreamgirls]
# 19   56bf6e823aeaaa14008c9629  ...              [2010,]
# 20   56bf6e823aeaaa14008c962a  ...            [Beyoncé]
# 23   56d43da72ccc5a1400d830be  ...              [B'Day]
# 24   56d43da72ccc5a1400d830bf  ...         [Dreamgirls]
# 28   56be88473aeaaa14008c9083  ...        [influential]
# 29   56be88473aeaaa14008c9084  ...             [Forbes]
# 30   56bf725c3aeaaa14008c9643  ...              [2000s]
# 31   56bf725c3aeaaa14008c9644  ...             [Forbes]
# 37   56d43f7e2ccc5a1400d830c9  ...                 [20]
# 38   56d43f7e2ccc5a1400d830cb  ...             [Forbes]
# 41   56be892d3aeaaa14008c908d  ...  [African-American,]
# 42   56be892d3aeaaa14008c908e  ...          [Methodist]
# 43   56bf74d53aeaaa14008c9659  ...              [Xerox]
# 45   56bf74d53aeaaa14008c965b  ...            [Solange]
# 47   56d440df2ccc5a1400d830d1  ...              [Xerox]
# 48   56d440df2ccc5a1400d830d2  ...              [salon]
# 49   56d440df2ccc5a1400d830d3  ...            [Solange]
# 51   56d440df2ccc5a1400d830d5  ...          [Methodist]
# 52   56be8a583aeaaa14008c9094  ...    [Fredericksburg,]
# 54   56be8a583aeaaa14008c9097  ...           [Houston,]
# 58   56bf76ef3aeaaa14008c9667  ...          ["Imagine"]
# 59   56d443ef2ccc5a1400d830db  ...    [Fredericksburg,]
# 61   56d443ef2ccc5a1400d830dd  ...             [seven,]
# 67   56bf79c73aeaaa14008c966e  ...               [1995]
# 71   56d45abf2ccc5a1400d830e5  ...             [eight,]
# 74   56d45abf2ccc5a1400d830e8  ...               [1995]
# 79   56bf7cb63aeaaa14008c9677  ...              [1996,]
# 87   56d45fcb2ccc5a1400d830fc  ...              [1999.]
# 89   56be8d423aeaaa14008c90b2  ...         [depression]
# 96   56d462f82ccc5a1400d83120  ...            [Beyoncé]
# 100  56be8e353aeaaa14008c90c7  ...             [eleven]
# 101  56be8e353aeaaa14008c90c8  ...                [MTV]
# 104  56bf89cfa10cfb1400551163  ...           [Survivor]
# 107  56d4831f2ccc5a1400d83156  ...           [Survivor]
#
# [40 rows x 8 columns]

# %%
def examples_to_feats(examples, tokenizer, max_len, max_query_len):
    """
    Converts examples of data into BERT input format tensors.
    """
    context_length_errors = 0
    feats = [] # list of dicts containing feature data
    for ex in tqdm(examples):
        question_raw = ' '.join(ex['question'])
        context_raw = ' '.join(ex['context'])
        if len(question_raw) > max_query_len: # check length of question, truncate if necessary
            question_raw = question_raw[:max_query_len]
        
        # encode the data using the BERT tokenizer
        encoded = tokenizer.encode_plus(question_raw, context_raw,
                                        max_length=max_len,
                                        padding='max_length',
                                        truncation=True,
                                        return_token_type_ids=True)
        if ex['is_impossible']:
            start = -1
            end = -1
        else: # Adjust the start_pos and end_pos to align with new tokenized question+context encodings
            input_ids = encoded['input_ids']
            answer_ids = tokenizer.encode(ex['answer']) # get token ids for answer to compare
            start, end = 0, 0 # defaults to this, if encode_plus performed truncation which included answer
            for i in range(len(input_ids)):
                if input_ids[i: i+len(answer_ids[1:-1])] == answer_ids[1:-1]:
                    start = i
                    end = i + len(answer_ids[1:-1]) - 1
                    break # found start and end pos ids in context
            
        ids = encoded['input_ids']
        token_type_ids = encoded['token_type_ids']
        mask = encoded['attention_mask']
        
        assert len(ids) == max_len
        assert len(token_type_ids) == max_len
        assert len(mask) == max_len
        
        feats.append({'ids': ids, # X
                      'token_type_ids': token_type_ids, # X
                      'mask': mask, # X
                      'start_pos': start, # y (target)
                      'end_pos': end}) # y (target)        
    return feats

# %% [markdown]
# ### BERT Fine Tuning for the SQuAD v2.0 Dataset
#
# We now must fine tune a BERT model using our training dataset:

# %%
# PROPERTIES
EPOCHS = 3
MAX_SEQ_LENGTH = 256
MAX_QUESTION_LENGTH = 64
BATCH_SIZE = 16
NUM_OUT = 2 # our output will be probability distribution over start token and end token
LEARNING_RATE = 2e-05

# %% [markdown]
# ### Loading the Training and Test Datasets

# %%
from torch.utils.data import TensorDataset, DataLoader

# %% [markdown]
# Load the train dataset:

# %%
# file names for pickled features
training_feats_file = 'training_features'
testing_feats_file = 'test_features'

# %%
if not os.path.exists(training_feats_file):
    training_features = examples_to_feats(training_examples, tokenizer, MAX_SEQ_LENGTH, MAX_QUESTION_LENGTH)
    torch.save(training_features, training_feats_file)
    print('Saved training_features to pickle (file): {}'.format(training_feats_file))

else:
    training_features = torch.load(training_feats_file)
    print('Training features loaded from file: {}\nNumber of features:{}'.format(training_feats_file, len(training_features)))

all_input_ids = torch.tensor([f['ids'] for f in training_features], dtype=torch.long)
all_input_mask = torch.tensor([f['mask'] for f in training_features], dtype=torch.long)
all_segment_ids = torch.tensor([f['token_type_ids'] for f in training_features], dtype=torch.long)


all_start_positions = torch.tensor([f['start_pos'] for f in training_features], dtype=torch.long)
all_end_positions = torch.tensor([f['end_pos'] for f in training_features], dtype=torch.long)
dataset = TensorDataset(all_input_ids, all_input_mask, all_segment_ids,
                        all_start_positions, all_end_positions)

train_params = train_params = {'batch_size': BATCH_SIZE,
                'shuffle': True,
                'num_workers': 0
                }

training_loader = DataLoader(dataset, **train_params)
# Out:
#  99%|█████████▉| 129376/130217 [10:04<00:04, 176.20it/s]
#  99%|█████████▉| 129395/130217 [10:04<00:04, 179.70it/s]
#  99%|█████████▉| 129417/130217 [10:04<00:04, 189.50it/s]
#  99%|█████████▉| 129437/130217 [10:04<00:04, 185.82it/s]
#  99%|█████████▉| 129456/130217 [10:04<00:04, 182.85it/s]
#  99%|█████████▉| 129475/130217 [10:04<00:04, 176.77it/s]
#  99%|█████████▉| 129493/130217 [10:05<00:04, 164.91it/s]
#  99%|█████████▉| 129510/130217 [10:05<00:05, 133.63it/s]
#  99%|█████████▉| 129526/130217 [10:05<00:04, 139.53it/s]
#  99%|█████████▉| 129545/130217 [10:05<00:04, 150.83it/s]
#  99%|█████████▉| 129564/130217 [10:05<00:04, 160.61it/s]
# 100%|█████████▉| 129587/130217 [10:05<00:03, 176.09it/s]
# 100%|█████████▉| 129611/130217 [10:05<00:03, 190.19it/s]
# 100%|█████████▉| 129632/130217 [10:05<00:03, 191.42it/s]
# 100%|█████████▉| 129653/130217 [10:05<00:02, 195.39it/s]
# 100%|█████████▉| 129674/130217 [10:06<00:02, 198.98it/s]
# 100%|█████████▉| 129695/130217 [10:06<00:02, 192.41it/s]
# 100%|█████████▉| 129715/130217 [10:06<00:02, 185.61it/s]
# 100%|█████████▉| 129734/130217 [10:06<00:02, 171.63it/s]
# 100%|█████████▉| 129752/130217 [10:06<00:02, 162.40it/s]
# 100%|█████████▉| 129769/130217 [10:06<00:02, 161.69it/s]
# 100%|█████████▉| 129786/130217 [10:06<00:02, 159.78it/s]
# 100%|█████████▉| 129805/130217 [10:06<00:02, 166.96it/s]
# 100%|█████████▉| 129824/130217 [10:06<00:02, 171.71it/s]
# 100%|█████████▉| 129842/130217 [10:07<00:02, 173.29it/s]
# 100%|█████████▉| 129860/130217 [10:07<00:02, 168.22it/s]
# 100%|█████████▉| 129877/130217 [10:07<00:02, 164.84it/s]
# 100%|█████████▉| 129895/130217 [10:07<00:01, 168.08it/s]
# 100%|█████████▉| 129912/130217 [10:07<00:01, 164.43it/s]
# 100%|█████████▉| 129929/130217 [10:07<00:01, 165.78it/s]
# 100%|█████████▉| 129947/130217 [10:07<00:01, 168.68it/s]
# 100%|█████████▉| 129964/130217 [10:07<00:01, 166.34it/s]
# 100%|█████████▉| 129981/130217 [10:07<00:01, 165.29it/s]
# 100%|█████████▉| 129999/130217 [10:07<00:01, 168.00it/s]
# 100%|█████████▉| 130016/130217 [10:08<00:01, 164.60it/s]
# 100%|█████████▉| 130036/130217 [10:08<00:01, 173.09it/s]
# 100%|█████████▉| 130054/130217 [10:08<00:00, 172.14it/s]
# 100%|█████████▉| 130075/130217 [10:08<00:00, 181.04it/s]
# 100%|█████████▉| 130094/130217 [10:08<00:00, 177.79it/s]
# 100%|█████████▉| 130112/130217 [10:08<00:00, 176.09it/s]
# 100%|█████████▉| 130130/130217 [10:08<00:00, 172.64it/s]
# 100%|█████████▉| 130150/130217 [10:08<00:00, 179.34it/s]
# 100%|█████████▉| 130170/130217 [10:08<00:00, 184.16it/s]
# 100%|█████████▉| 130189/130217 [10:09<00:00, 181.87it/s]
# 100%|██████████| 130217/130217 [10:09<00:00, 213.75it/s]
# Saved training_features to pickle (file): training_features

# %% [markdown]
# Load the test dataset:

# %%
test_examples = preprocess_data(test_json, tokenized=True)
# Out:
# 100%|██████████| 35/35 [00:06<00:00,  5.43it/s]
# Total number of questions:11873
# Total number of impossible questions:5945
# Number of tokenization errors:15
# Number of misaligned answer errors:0

# %%
if not os.path.exists(testing_feats_file):
    test_features = examples_to_feats(test_examples, tokenizer, MAX_SEQ_LENGTH, MAX_QUESTION_LENGTH)
    torch.save(test_features, testing_feats_file)
    print('Saved test_features to pickle (file): {}'.format(testing_feats_file))
else:
    test_features = torch.load(testing_feats_file)
    print('Testing features loaded from file: {}\nNumber of features:{}'.format(testing_feats_file, len(test_features)))

all_input_ids = torch.tensor([f['ids'] for f in test_features], dtype=torch.long)
all_input_mask = torch.tensor([f['mask'] for f in test_features], dtype=torch.long)
all_segment_ids = torch.tensor([f['token_type_ids'] for f in test_features], dtype=torch.long)

all_start_positions = torch.tensor([f['start_pos'] for f in test_features], dtype=torch.long)
all_end_positions = torch.tensor([f['end_pos'] for f in test_features], dtype=torch.long)

test_dataset = TensorDataset(all_input_ids, all_input_mask, all_segment_ids, 
                             all_start_positions, all_end_positions)

test_params = {'batch_size': BATCH_SIZE,
                'shuffle': True,
                'num_workers': 0
                }    

testing_loader = DataLoader(test_dataset, **train_params)
# Out:
# Testing features loaded from file: test_features
# Number of features:26232

# %%
def train(model, training_loader, optimizer):
    print('Starting training...')
    step = 0
    loss_tracker = 0
    model.zero_grad()
    model.train()
    for data in tqdm(training_loader):
        data = tuple(d.to(device) for d in data)
        inputs = {'input_ids':     data[0],
                'attention_mask':  data[1], 
                'token_type_ids':  data[2],  
                'start_positions': data[3], 
                'end_positions':   data[4]}
        outputs = model(**inputs)
        loss = outputs[0]
        loss.backward() # back propagation
        optimizer.step()
        model.zero_grad()
        loss_tracker += loss.item()
        step += 1
        if step % 100 == 0:
            print("Train loss: {}".format(loss_tracker/step))

    return loss

def validation(model, testing_loader):
    print('Starting validation...')
    model.eval()
    preds = []
    targs = []
    with torch.no_grad():
        for data in tqdm(testing_loader):
            data = tuple(d.to(device) for d in data)
            inputs = {'input_ids': data[0],
                'attention_mask':  data[1], 
                'token_type_ids':  data[2]}
            output = model(**inputs)
            starts = output[0]
            ends = output[1]
            start_preds = []
            end_preds = []

            for s in starts:
                start_pred = torch.argmax(s)
                start_preds.append(start_pred)
            for e in ends:
                end_pred = torch.argmax(e)
                end_preds.append(end_pred)
            
            for s, e in zip(start_preds, end_preds):
                preds.append((s,e))

            target_starts = data[3]
            target_ends = data[4]

            for s,e in zip(target_starts, target_ends):
                targs.append((s,e))
            
    return preds, targs

# %% [markdown]
# ### Fine Tuning the BertForQuestionAnswering Model

# %%
model = BertForQuestionAnswering.from_pretrained('bert-base-uncased')
model.to(device)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForQuestionAnswering: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForQuestionAnswering were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['qa_outputs.weight', 'qa_outputs.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BertForQuestionAnswering(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (qa_outputs): Linear(in_features=768, out_features=2, bias=True)
# )

# %%
optimizer = torch.optim.Adam(params=model.parameters(), lr=LEARNING_RATE)

# %%
for epoch in range(EPOCHS): #TRAINING
    loss = train(model, training_loader, optimizer)
    print(f'Epoch: {epoch}, Loss:  {loss.item()}')
# Out:
#  99%|█████████▉| 8096/8139 [1:48:44<00:34,  1.24it/s]
#  99%|█████████▉| 8097/8139 [1:48:45<00:33,  1.24it/s]
#  99%|█████████▉| 8098/8139 [1:48:46<00:33,  1.24it/s]
# 100%|█████████▉| 8099/8139 [1:48:46<00:32,  1.24it/s]
# 100%|█████████▉| 8100/8139 [1:48:47<00:31,  1.24it/s]
# Train loss: 1.4102776688171759
# 100%|█████████▉| 8101/8139 [1:48:48<00:30,  1.24it/s]
# 100%|█████████▉| 8102/8139 [1:48:49<00:29,  1.24it/s]
# 100%|█████████▉| 8103/8139 [1:48:50<00:29,  1.24it/s]
# 100%|█████████▉| 8104/8139 [1:48:51<00:28,  1.24it/s]
# 100%|█████████▉| 8105/8139 [1:48:51<00:27,  1.24it/s]
# 100%|█████████▉| 8106/8139 [1:48:52<00:26,  1.23it/s]
# 100%|█████████▉| 8107/8139 [1:48:53<00:25,  1.23it/s]
# 100%|█████████▉| 8108/8139 [1:48:54<00:25,  1.24it/s]
# 100%|█████████▉| 8109/8139 [1:48:55<00:24,  1.23it/s]
# 100%|█████████▉| 8110/8139 [1:48:55<00:23,  1.24it/s]
# 100%|█████████▉| 8111/8139 [1:48:56<00:22,  1.23it/s]
# 100%|█████████▉| 8112/8139 [1:48:57<00:21,  1.24it/s]
# 100%|█████████▉| 8113/8139 [1:48:58<00:20,  1.24it/s]
# 100%|█████████▉| 8114/8139 [1:48:59<00:20,  1.24it/s]
# 100%|█████████▉| 8115/8139 [1:48:59<00:19,  1.24it/s]
# 100%|█████████▉| 8116/8139 [1:49:00<00:18,  1.24it/s]
# 100%|█████████▉| 8117/8139 [1:49:01<00:17,  1.24it/s]
# 100%|█████████▉| 8118/8139 [1:49:02<00:16,  1.24it/s]
# 100%|█████████▉| 8119/8139 [1:49:03<00:16,  1.24it/s]
# 100%|█████████▉| 8120/8139 [1:49:03<00:15,  1.23it/s]
# 100%|█████████▉| 8121/8139 [1:49:04<00:14,  1.23it/s]
# 100%|█████████▉| 8122/8139 [1:49:05<00:13,  1.23it/s]
# 100%|█████████▉| 8123/8139 [1:49:06<00:12,  1.24it/s]
# 100%|█████████▉| 8124/8139 [1:49:07<00:12,  1.24it/s]
# 100%|█████████▉| 8125/8139 [1:49:08<00:11,  1.24it/s]
# 100%|█████████▉| 8126/8139 [1:49:08<00:10,  1.24it/s]
# 100%|█████████▉| 8127/8139 [1:49:09<00:09,  1.24it/s]
# 100%|█████████▉| 8128/8139 [1:49:10<00:08,  1.24it/s]
# 100%|█████████▉| 8129/8139 [1:49:11<00:08,  1.23it/s]
# 100%|█████████▉| 8130/8139 [1:49:12<00:07,  1.24it/s]
# 100%|█████████▉| 8131/8139 [1:49:12<00:06,  1.24it/s]
# 100%|█████████▉| 8132/8139 [1:49:13<00:05,  1.24it/s]
# 100%|█████████▉| 8133/8139 [1:49:14<00:04,  1.24it/s]
# 100%|█████████▉| 8134/8139 [1:49:15<00:04,  1.24it/s]
# 100%|█████████▉| 8135/8139 [1:49:16<00:03,  1.24it/s]
# 100%|█████████▉| 8136/8139 [1:49:16<00:02,  1.24it/s]
# 100%|█████████▉| 8137/8139 [1:49:17<00:01,  1.24it/s]
# 100%|█████████▉| 8138/8139 [1:49:18<00:00,  1.24it/s]
# 100%|██████████| 8139/8139 [1:49:19<00:00,  1.24it/s]
# Epoch: 0, Loss:  0.9089405536651611

# %% [markdown]
# Save the model with new weights for future use:

# %%
model_pretrained = model.module if hasattr(model, 'module') else model
model_pretrained.save_pretrained('BERTQAPretrained')

# %% [markdown]
# ### Validation on the Test Dataset

# %%
preds, targs = validation(model, testing_loader)
preds
# Out:
#  82%|████████▏ | 1339/1640 [05:49<01:22,  3.64it/s]
#
#  82%|████████▏ | 1340/1640 [05:49<01:21,  3.67it/s]
#
#  82%|████████▏ | 1341/1640 [05:49<01:21,  3.66it/s]
#
#  82%|████████▏ | 1342/1640 [05:50<01:21,  3.67it/s]
#
#  82%|████████▏ | 1343/1640 [05:50<01:21,  3.66it/s]
#
#  82%|████████▏ | 1344/1640 [05:50<01:20,  3.67it/s]
#
#  82%|████████▏ | 1345/1640 [05:50<01:20,  3.66it/s]
#
#  82%|████████▏ | 1346/1640 [05:51<01:20,  3.66it/s]
#
#  82%|████████▏ | 1347/1640 [05:51<01:20,  3.65it/s]
#
#  82%|████████▏ | 1348/1640 [05:51<01:19,  3.66it/s]
#
#  82%|████████▏ | 1349/1640 [05:52<01:19,  3.66it/s]
#
#  82%|████████▏ | 1350/1640 [05:52<01:19,  3.66it/s]
#
#  82%|████████▏ | 1351/1640 [05:52<01:18,  3.66it/s]
#
#  82%|████████▏ | 1352/1640 [05:52<01:18,  3.67it/s]
#
#  82%|████████▎ | 1353/1640 [05:53<01:18,  3.65it/s]
#
#  83%|████████▎ | 1354/1640 [05:53<01:18,  3.66it/s]
#
#  83%|████████▎ | 1355/1640 [05:53<01:18,  3.65it/s]
#
#  83%|████████▎ | 1356/1640 [05:53<01:17,  3.67it/s]
#
#  83%|████████▎ | 1357/1640 [05:54<01:17,  3.66it/s]
#
#  83%|████████▎ | 1358/1640 [05:54<01:17,  3.66it/s]
#
#  83%|████████▎ | 1359/1640 [05:54<01:16,  3.65it/s]
#
#  83%|████████▎ | 1360/1640 [05:55<01:16,  3.64it/s]
#
#  83%|████████▎ | 1361/1640 [05:55<01:16,  3.66it/s]
#
#  83%|████████▎ | 1362/1640 [05:55<01:15,  3.67it/s]
#
#  83%|████████▎ | 1363/1640 [05:55<01:15,  3.66it/s]
#
#  83%|████████▎ | 1364/1640 [05:56<01:15,  3.66it/s]
#
#  83%|████████▎ | 1365/1640 [05:56<01:15,  3.65it/s]
#
#  83%|████████▎ | 1366/1640 [05:56<01:14,  3.66it/s]
#
#  83%|████████▎ | 1367/1640 [05:56<01:14,  3.66it/s]
#
#  83%|████████▎ | 1368/1640 [05:57<01:14,  3.67it/s]
#
#  83%|████████▎ | 1369/1640 [05:57<01:14,  3.65it/s]
#
#  84%|████████▎ | 1370/1640 [05:57<01:13,  3.66it/s]
#
#  84%|████████▎ | 1371/1640 [05:58<01:13,  3.66it/s]
#
#  84%|████████▎ | 1372/1640 [05:58<01:13,  3.66it/s]
#
#  84%|████████▎ | 1373/1640 [05:58<01:12,  3.66it/s]
#
#  84%|████████▍ | 1374/1640 [05:58<01:12,  3.66it/s]
#
#  84%|████████▍ | 1375/1640 [05:59<01:12,  3.66it/s]
#
#  84%|████████▍ | 1376/1640 [05:59<01:12,  3.66it/s]
#
#  84%|████████▍ | 1377/1640 [05:59<01:11,  3.66it/s]
#
#  84%|████████▍ | 1378/1640 [05:59<01:11,  3.66it/s]
#
#  84%|████████▍ | 1379/1640 [06:00<01:11,  3.66it/s]
#
#  84%|████████▍ | 1380/1640 [06:00<01:11,  3.65it/s]
#
#  84%|████████▍ | 1381/1640 [06:00<01:10,  3.65it/s]
#
#  84%|████████▍ | 1382/1640 [06:01<01:10,  3.66it/s]
#
#  84%|████████▍ | 1383/1640 [06:01<01:10,  3.66it/s]
#
#  84%|████████▍ | 1384/1640 [06:01<01:10,  3.66it/s]
#
#  84%|████████▍ | 1385/1640 [06:01<01:09,  3.66it/s]
#
#  85%|████████▍ | 1386/1640 [06:02<01:09,  3.65it/s]
#
#  85%|████████▍ | 1387/1640 [06:02<01:08,  3.67it/s]
#
#  85%|████████▍ | 1388/1640 [06:02<01:08,  3.67it/s]
#
#  85%|████████▍ | 1389/1640 [06:02<01:08,  3.66it/s]
#
#  85%|████████▍ | 1390/1640 [06:03<01:07,  3.68it/s]
#
#  85%|████████▍ | 1391/1640 [06:03<01:08,  3.65it/s]
#
#  85%|████████▍ | 1392/1640 [06:03<01:07,  3.67it/s]
#
#  85%|████████▍ | 1393/1640 [06:04<01:07,  3.66it/s]
#
#  85%|████████▌ | 1394/1640 [06:04<01:07,  3.67it/s]
#
#  85%|████████▌ | 1395/1640 [06:04<01:06,  3.66it/s]
#
#  85%|████████▌ | 1396/1640 [06:04<01:06,  3.67it/s]
#
#  85%|████████▌ | 1397/1640 [06:05<01:06,  3.67it/s]
#
#  85%|████████▌ | 1398/1640 [06:05<01:06,  3.66it/s]
#
#  85%|████████▌ | 1399/1640 [06:05<01:05,  3.66it/s]
#
#  85%|████████▌ | 1400/1640 [06:05<01:05,  3.64it/s]
#
#  85%|████████▌ | 1401/1640 [06:06<01:04,  3.68it/s]
#
#  85%|████████▌ | 1402/1640 [06:06<01:05,  3.66it/s]
#
#  86%|████████▌ | 1403/1640 [06:06<01:04,  3.66it/s]
#
#  86%|████████▌ | 1404/1640 [06:07<01:04,  3.66it/s]
#
#  86%|████████▌ | 1405/1640 [06:07<01:04,  3.67it/s]
#
#  86%|████████▌ | 1406/1640 [06:07<01:04,  3.65it/s]
#
#  86%|████████▌ | 1407/1640 [06:07<01:03,  3.67it/s]
#
#  86%|████████▌ | 1408/1640 [06:08<01:03,  3.66it/s]
#
#  86%|████████▌ | 1409/1640 [06:08<01:03,  3.66it/s]
#
#  86%|████████▌ | 1410/1640 [06:08<01:02,  3.66it/s]
#
#  86%|████████▌ | 1411/1640 [06:08<01:02,  3.68it/s]
#
#  86%|████████▌ | 1412/1640 [06:09<01:02,  3.66it/s]
#
#  86%|████████▌ | 1413/1640 [06:09<01:01,  3.66it/s]
#
#  86%|████████▌ | 1414/1640 [06:09<01:01,  3.66it/s]
#
#  86%|████████▋ | 1415/1640 [06:10<01:01,  3.67it/s]
#
#  86%|████████▋ | 1416/1640 [06:10<01:01,  3.66it/s]
#
#  86%|████████▋ | 1417/1640 [06:10<01:01,  3.65it/s]
#
#  86%|████████▋ | 1418/1640 [06:10<01:00,  3.67it/s]
#
#  87%|████████▋ | 1419/1640 [06:11<01:00,  3.67it/s]
#
#  87%|████████▋ | 1420/1640 [06:11<01:00,  3.66it/s]
#
#  87%|████████▋ | 1421/1640 [06:11<00:59,  3.66it/s]
#
#  87%|████████▋ | 1422/1640 [06:11<00:59,  3.66it/s]
#
#  87%|████████▋ | 1423/1640 [06:12<00:59,  3.68it/s]
#
#  87%|████████▋ | 1424/1640 [06:12<00:59,  3.65it/s]
#
#  87%|████████▋ | 1425/1640 [06:12<00:58,  3.67it/s]
#
#  87%|████████▋ | 1426/1640 [06:13<00:58,  3.66it/s]
#
#  87%|████████▋ | 1427/1640 [06:13<00:58,  3.67it/s]
#
#  87%|████████▋ | 1428/1640 [06:13<00:58,  3.64it/s]
#
#  87%|████████▋ | 1429/1640 [06:13<00:57,  3.67it/s]
#
#  87%|████████▋ | 1430/1640 [06:14<00:57,  3.66it/s]
#
#  87%|████████▋ | 1431/1640 [06:14<00:57,  3.65it/s]
#
#  87%|████████▋ | 1432/1640 [06:14<00:56,  3.66it/s]
#
#  87%|████████▋ | 1433/1640 [06:14<00:56,  3.67it/s]
#
#  87%|████████▋ | 1434/1640 [06:15<00:56,  3.66it/s]
#
#  88%|████████▊ | 1435/1640 [06:15<00:55,  3.66it/s]
#
#  88%|████████▊ | 1436/1640 [06:15<00:55,  3.66it/s]
#
#  88%|████████▊ | 1437/1640 [06:16<00:55,  3.67it/s]
#
#  88%|████████▊ | 1438/1640 [06:16<00:55,  3.66it/s]
#
#  88%|████████▊ | 1439/1640 [06:16<00:54,  3.66it/s]
#
#  88%|████████▊ | 1440/1640 [06:16<00:54,  3.67it/s]
#
#  88%|████████▊ | 1441/1640 [06:17<00:54,  3.68it/s]
#
#  88%|████████▊ | 1442/1640 [06:17<00:53,  3.67it/s]
#
#  88%|████████▊ | 1443/1640 [06:17<00:53,  3.67it/s]
#
#  88%|████████▊ | 1444/1640 [06:17<00:53,  3.67it/s]
#
#  88%|████████▊ | 1445/1640 [06:18<00:53,  3.68it/s]
#
#  88%|████████▊ | 1446/1640 [06:18<00:52,  3.68it/s]
#
#  88%|████████▊ | 1447/1640 [06:18<00:52,  3.65it/s]
#
#  88%|████████▊ | 1448/1640 [06:19<00:52,  3.67it/s]
#
#  88%|████████▊ | 1449/1640 [06:19<00:52,  3.66it/s]
#
#  88%|████████▊ | 1450/1640 [06:19<00:51,  3.67it/s]
#
#  88%|████████▊ | 1451/1640 [06:19<00:51,  3.66it/s]
#
#  89%|████████▊ | 1452/1640 [06:20<00:51,  3.67it/s]
#
#  89%|████████▊ | 1453/1640 [06:20<00:50,  3.67it/s]
#
#  89%|████████▊ | 1454/1640 [06:20<00:50,  3.66it/s]
#
#  89%|████████▊ | 1455/1640 [06:20<00:50,  3.66it/s]
#
#  89%|████████▉ | 1456/1640 [06:21<00:50,  3.66it/s]
#
#  89%|████████▉ | 1457/1640 [06:21<00:49,  3.67it/s]
#
#  89%|████████▉ | 1458/1640 [06:21<00:49,  3.65it/s]
#
#  89%|████████▉ | 1459/1640 [06:22<00:49,  3.68it/s]
#
#  89%|████████▉ | 1460/1640 [06:22<00:49,  3.67it/s]
#
#  89%|████████▉ | 1461/1640 [06:22<00:48,  3.66it/s]
#
#  89%|████████▉ | 1462/1640 [06:22<00:48,  3.66it/s]
#
#  89%|████████▉ | 1463/1640 [06:23<00:48,  3.66it/s]
#
#  89%|████████▉ | 1464/1640 [06:23<00:48,  3.64it/s]
#
#  89%|████████▉ | 1465/1640 [06:23<00:47,  3.67it/s]
#
#  89%|████████▉ | 1466/1640 [06:23<00:47,  3.67it/s]
#
#  89%|████████▉ | 1467/1640 [06:24<00:47,  3.67it/s]
#
#  90%|████████▉ | 1468/1640 [06:24<00:46,  3.67it/s]
#
#  90%|████████▉ | 1469/1640 [06:24<00:46,  3.66it/s]
#
#  90%|████████▉ | 1470/1640 [06:25<00:46,  3.67it/s]
#
#  90%|████████▉ | 1471/1640 [06:25<00:46,  3.66it/s]
#
#  90%|████████▉ | 1472/1640 [06:25<00:45,  3.67it/s]
#
#  90%|████████▉ | 1473/1640 [06:25<00:45,  3.67it/s]
#
#  90%|████████▉ | 1474/1640 [06:26<00:45,  3.67it/s]
#
#  90%|████████▉ | 1475/1640 [06:26<00:44,  3.67it/s]
#
#  90%|█████████ | 1476/1640 [06:26<00:44,  3.67it/s]
#
#  90%|█████████ | 1477/1640 [06:26<00:44,  3.68it/s]
#
#  90%|█████████ | 1478/1640 [06:27<00:44,  3.66it/s]
#
#  90%|█████████ | 1479/1640 [06:27<00:43,  3.67it/s]
#
#  90%|█████████ | 1480/1640 [06:27<00:43,  3.66it/s]
#
#  90%|█████████ | 1481/1640 [06:28<00:43,  3.67it/s]
#
#  90%|█████████ | 1482/1640 [06:28<00:43,  3.67it/s]
#
#  90%|█████████ | 1483/1640 [06:28<00:42,  3.67it/s]
#
#  90%|█████████ | 1484/1640 [06:28<00:42,  3.67it/s]
#
#  91%|█████████ | 1485/1640 [06:29<00:42,  3.66it/s]
#
#  91%|█████████ | 1486/1640 [06:29<00:41,  3.67it/s]
#
#  91%|█████████ | 1487/1640 [06:29<00:41,  3.67it/s]
#
#  91%|█████████ | 1488/1640 [06:29<00:41,  3.66it/s]
#
#  91%|█████████ | 1489/1640 [06:30<00:41,  3.66it/s]
#
#  91%|█████████ | 1490/1640 [06:30<00:40,  3.66it/s]
#
#  91%|█████████ | 1491/1640 [06:30<00:40,  3.67it/s]
#
#  91%|█████████ | 1492/1640 [06:31<00:40,  3.66it/s]
#
#  91%|█████████ | 1493/1640 [06:31<00:40,  3.67it/s]
#
#  91%|█████████ | 1494/1640 [06:31<00:39,  3.67it/s]
#
#  91%|█████████ | 1495/1640 [06:31<00:39,  3.67it/s]
#
#  91%|█████████ | 1496/1640 [06:32<00:39,  3.65it/s]
#
#  91%|█████████▏| 1497/1640 [06:32<00:39,  3.66it/s]
#
#  91%|█████████▏| 1498/1640 [06:32<00:38,  3.66it/s]
#
#  91%|█████████▏| 1499/1640 [06:32<00:38,  3.66it/s]
#
#  91%|█████████▏| 1500/1640 [06:33<00:38,  3.66it/s]
#
#  92%|█████████▏| 1501/1640 [06:33<00:38,  3.66it/s]
#
#  92%|█████████▏| 1502/1640 [06:33<00:37,  3.66it/s]
#
#  92%|█████████▏| 1503/1640 [06:34<00:37,  3.67it/s]
#
#  92%|█████████▏| 1504/1640 [06:34<00:37,  3.66it/s]
#
#  92%|█████████▏| 1505/1640 [06:34<00:36,  3.67it/s]
#
#  92%|█████████▏| 1506/1640 [06:34<00:36,  3.66it/s]
#
#  92%|█████████▏| 1507/1640 [06:35<00:36,  3.67it/s]
#
#  92%|█████████▏| 1508/1640 [06:35<00:36,  3.66it/s]
#
#  92%|█████████▏| 1509/1640 [06:35<00:35,  3.67it/s]
#
#  92%|█████████▏| 1510/1640 [06:35<00:35,  3.66it/s]
#
#  92%|█████████▏| 1511/1640 [06:36<00:35,  3.66it/s]
#
#  92%|█████████▏| 1512/1640 [06:36<00:34,  3.66it/s]
#
#  92%|█████████▏| 1513/1640 [06:36<00:34,  3.66it/s]
#
#  92%|█████████▏| 1514/1640 [06:37<00:34,  3.66it/s]
#
#  92%|█████████▏| 1515/1640 [06:37<00:34,  3.66it/s]
#
#  92%|█████████▏| 1516/1640 [06:37<00:33,  3.65it/s]
#
#  92%|█████████▎| 1517/1640 [06:37<00:33,  3.67it/s]
#
#  93%|█████████▎| 1518/1640 [06:38<00:33,  3.66it/s]
#
#  93%|█████████▎| 1519/1640 [06:38<00:33,  3.66it/s]
#
#  93%|█████████▎| 1520/1640 [06:38<00:32,  3.66it/s]
#
#  93%|█████████▎| 1521/1640 [06:38<00:32,  3.66it/s]
#
#  93%|█████████▎| 1522/1640 [06:39<00:32,  3.65it/s]
#
#  93%|█████████▎| 1523/1640 [06:39<00:31,  3.66it/s]
#
#  93%|█████████▎| 1524/1640 [06:39<00:31,  3.66it/s]
#
#  93%|█████████▎| 1525/1640 [06:40<00:31,  3.67it/s]
#
#  93%|█████████▎| 1526/1640 [06:40<00:31,  3.66it/s]
#
#  93%|█████████▎| 1527/1640 [06:40<00:30,  3.67it/s]
#
#  93%|█████████▎| 1528/1640 [06:40<00:30,  3.66it/s]
#
#  93%|█████████▎| 1529/1640 [06:41<00:30,  3.67it/s]
#
#  93%|█████████▎| 1530/1640 [06:41<00:30,  3.67it/s]
#
#  93%|█████████▎| 1531/1640 [06:41<00:29,  3.66it/s]
#
#  93%|█████████▎| 1532/1640 [06:41<00:29,  3.67it/s]
#
#  93%|█████████▎| 1533/1640 [06:42<00:29,  3.66it/s]
#
#  94%|█████████▎| 1534/1640 [06:42<00:28,  3.67it/s]
#
#  94%|█████████▎| 1535/1640 [06:42<00:28,  3.66it/s]
#
#  94%|█████████▎| 1536/1640 [06:43<00:28,  3.67it/s]
#
#  94%|█████████▎| 1537/1640 [06:43<00:28,  3.66it/s]
#
#  94%|█████████▍| 1538/1640 [06:43<00:27,  3.66it/s]
#
#  94%|█████████▍| 1539/1640 [06:43<00:27,  3.64it/s]
#
#  94%|█████████▍| 1540/1640 [06:44<00:27,  3.67it/s]
#
#  94%|█████████▍| 1541/1640 [06:44<00:27,  3.66it/s]
#
#  94%|█████████▍| 1542/1640 [06:44<00:26,  3.66it/s]
#
#  94%|█████████▍| 1543/1640 [06:44<00:26,  3.67it/s]
#
#  94%|█████████▍| 1544/1640 [06:45<00:26,  3.68it/s]
#
#  94%|█████████▍| 1545/1640 [06:45<00:25,  3.66it/s]
#
#  94%|█████████▍| 1546/1640 [06:45<00:25,  3.67it/s]
#
#  94%|█████████▍| 1547/1640 [06:46<00:25,  3.66it/s]
#
#  94%|█████████▍| 1548/1640 [06:46<00:25,  3.67it/s]
#
#  94%|█████████▍| 1549/1640 [06:46<00:24,  3.66it/s]
#
#  95%|█████████▍| 1550/1640 [06:46<00:24,  3.65it/s]
#
#  95%|█████████▍| 1551/1640 [06:47<00:24,  3.66it/s]
#
#  95%|█████████▍| 1552/1640 [06:47<00:24,  3.67it/s]
#
#  95%|█████████▍| 1553/1640 [06:47<00:23,  3.66it/s]
#
#  95%|█████████▍| 1554/1640 [06:47<00:23,  3.67it/s]
#
#  95%|█████████▍| 1555/1640 [06:48<00:23,  3.67it/s]
#
#  95%|█████████▍| 1556/1640 [06:48<00:22,  3.65it/s]
#
#  95%|█████████▍| 1557/1640 [06:48<00:22,  3.66it/s]
#
#  95%|█████████▌| 1558/1640 [06:49<00:22,  3.66it/s]
#
#  95%|█████████▌| 1559/1640 [06:49<00:22,  3.66it/s]
#
#  95%|█████████▌| 1560/1640 [06:49<00:21,  3.65it/s]
#
#  95%|█████████▌| 1561/1640 [06:49<00:21,  3.66it/s]
#
#  95%|█████████▌| 1562/1640 [06:50<00:21,  3.67it/s]
#
#  95%|█████████▌| 1563/1640 [06:50<00:21,  3.66it/s]
#
#  95%|█████████▌| 1564/1640 [06:50<00:20,  3.66it/s]
#
#  95%|█████████▌| 1565/1640 [06:50<00:20,  3.68it/s]
#
#  95%|█████████▌| 1566/1640 [06:51<00:20,  3.66it/s]
#
#  96%|█████████▌| 1567/1640 [06:51<00:19,  3.66it/s]
#
#  96%|█████████▌| 1568/1640 [06:51<00:19,  3.66it/s]
#
#  96%|█████████▌| 1569/1640 [06:52<00:19,  3.67it/s]
#
#  96%|█████████▌| 1570/1640 [06:52<00:19,  3.65it/s]
#
#  96%|█████████▌| 1571/1640 [06:52<00:18,  3.68it/s]
#
#  96%|█████████▌| 1572/1640 [06:52<00:18,  3.67it/s]
#
#  96%|█████████▌| 1573/1640 [06:53<00:18,  3.66it/s]
#
#  96%|█████████▌| 1574/1640 [06:53<00:18,  3.66it/s]
#
#  96%|█████████▌| 1575/1640 [06:53<00:17,  3.67it/s]
#
#  96%|█████████▌| 1576/1640 [06:53<00:17,  3.67it/s]
#
#  96%|█████████▌| 1577/1640 [06:54<00:17,  3.67it/s]
#
#  96%|█████████▌| 1578/1640 [06:54<00:16,  3.66it/s]
#
#  96%|█████████▋| 1579/1640 [06:54<00:16,  3.67it/s]
#
#  96%|█████████▋| 1580/1640 [06:55<00:16,  3.66it/s]
#
#  96%|█████████▋| 1581/1640 [06:55<00:16,  3.67it/s]
#
#  96%|█████████▋| 1582/1640 [06:55<00:15,  3.66it/s]
#
#  97%|█████████▋| 1583/1640 [06:55<00:15,  3.67it/s]
#
#  97%|█████████▋| 1584/1640 [06:56<00:15,  3.67it/s]
#
#  97%|█████████▋| 1585/1640 [06:56<00:14,  3.67it/s]
#
#  97%|█████████▋| 1586/1640 [06:56<00:14,  3.67it/s]
#
#  97%|█████████▋| 1587/1640 [06:56<00:14,  3.66it/s]
#
#  97%|█████████▋| 1588/1640 [06:57<00:14,  3.67it/s]
#
#  97%|█████████▋| 1589/1640 [06:57<00:13,  3.67it/s]
#
#  97%|█████████▋| 1590/1640 [06:57<00:13,  3.68it/s]
#
#  97%|█████████▋| 1591/1640 [06:58<00:13,  3.67it/s]
#
#  97%|█████████▋| 1592/1640 [06:58<00:13,  3.66it/s]
#
#  97%|█████████▋| 1593/1640 [06:58<00:12,  3.66it/s]
#
#  97%|█████████▋| 1594/1640 [06:58<00:12,  3.67it/s]
#
#  97%|█████████▋| 1595/1640 [06:59<00:12,  3.67it/s]
#
#  97%|█████████▋| 1596/1640 [06:59<00:11,  3.67it/s]
#
#  97%|█████████▋| 1597/1640 [06:59<00:11,  3.68it/s]
#
#  97%|█████████▋| 1598/1640 [06:59<00:11,  3.67it/s]
#
#  98%|█████████▊| 1599/1640 [07:00<00:11,  3.67it/s]
#
#  98%|█████████▊| 1600/1640 [07:00<00:10,  3.67it/s]
#
#  98%|█████████▊| 1601/1640 [07:00<00:10,  3.66it/s]
#
#  98%|█████████▊| 1602/1640 [07:01<00:10,  3.65it/s]
#
#  98%|█████████▊| 1603/1640 [07:01<00:10,  3.67it/s]
#
#  98%|█████████▊| 1604/1640 [07:01<00:09,  3.66it/s]
#
#  98%|█████████▊| 1605/1640 [07:01<00:09,  3.66it/s]
#
#  98%|█████████▊| 1606/1640 [07:02<00:09,  3.66it/s]
#
#  98%|█████████▊| 1607/1640 [07:02<00:08,  3.67it/s]
#
#  98%|█████████▊| 1608/1640 [07:02<00:08,  3.67it/s]
#
#  98%|█████████▊| 1609/1640 [07:02<00:08,  3.66it/s]
#
#  98%|█████████▊| 1610/1640 [07:03<00:08,  3.68it/s]
#
#  98%|█████████▊| 1611/1640 [07:03<00:07,  3.66it/s]
#
#  98%|█████████▊| 1612/1640 [07:03<00:07,  3.68it/s]
#
#  98%|█████████▊| 1613/1640 [07:04<00:07,  3.66it/s]
#
#  98%|█████████▊| 1614/1640 [07:04<00:07,  3.67it/s]
#
#  98%|█████████▊| 1615/1640 [07:04<00:06,  3.66it/s]
#
#  99%|█████████▊| 1616/1640 [07:04<00:06,  3.67it/s]
#
#  99%|█████████▊| 1617/1640 [07:05<00:06,  3.66it/s]
#
#  99%|█████████▊| 1618/1640 [07:05<00:05,  3.67it/s]
#
#  99%|█████████▊| 1619/1640 [07:05<00:05,  3.66it/s]
#
#  99%|█████████▉| 1620/1640 [07:05<00:05,  3.67it/s]
#
#  99%|█████████▉| 1621/1640 [07:06<00:05,  3.67it/s]
#
#  99%|█████████▉| 1622/1640 [07:06<00:04,  3.66it/s]
#
#  99%|█████████▉| 1623/1640 [07:06<00:04,  3.67it/s]
#
#  99%|█████████▉| 1624/1640 [07:07<00:04,  3.65it/s]
#
#  99%|█████████▉| 1625/1640 [07:07<00:04,  3.67it/s]
#
#  99%|█████████▉| 1626/1640 [07:07<00:03,  3.67it/s]
#
#  99%|█████████▉| 1627/1640 [07:07<00:03,  3.67it/s]
#
#  99%|█████████▉| 1628/1640 [07:08<00:03,  3.66it/s]
#
#  99%|█████████▉| 1629/1640 [07:08<00:03,  3.66it/s]
#
#  99%|█████████▉| 1630/1640 [07:08<00:02,  3.66it/s]
#
#  99%|█████████▉| 1631/1640 [07:08<00:02,  3.67it/s]
#
# 100%|█████████▉| 1632/1640 [07:09<00:02,  3.65it/s]
#
# 100%|█████████▉| 1633/1640 [07:09<00:01,  3.65it/s]
#
# 100%|█████████▉| 1634/1640 [07:09<00:01,  3.66it/s]
#
# 100%|█████████▉| 1635/1640 [07:10<00:01,  3.66it/s]
#
# 100%|█████████▉| 1636/1640 [07:10<00:01,  3.67it/s]
#
# 100%|█████████▉| 1637/1640 [07:10<00:00,  3.67it/s]
#
# 100%|█████████▉| 1638/1640 [07:10<00:00,  3.67it/s]
#
# 100%|█████████▉| 1639/1640 [07:11<00:00,  3.67it/s]
#
# 100%|██████████| 1640/1640 [07:11<00:00,  3.80it/s]
# [(tensor(65, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(53, device='cuda:0'), tensor(57, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(14, device='cuda:0'), tensor(14, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(24, device='cuda:0'), tensor(24, device='cuda:0')),
#  (tensor(142, device='cuda:0'), tensor(145, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(26, device='cuda:0'), tensor(26, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(123, device='cuda:0')),
#  (tensor(41, device='cuda:0'), tensor(41, device='cuda:0')),
#  (tensor(14, device='cuda:0'), tensor(15, device='cuda:0')),
#  (tensor(49, device='cuda:0'), tensor(73, device='cuda:0')),
#  (tensor(31, device='cuda:0'), tensor(35, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(192, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(47, device='cuda:0'), tensor(49, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(97, device='cuda:0'), tensor(98, device='cuda:0')),
#  (tensor(31, device='cuda:0'), tensor(32, device='cuda:0')),
#  (tensor(130, device='cuda:0'), tensor(130, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(17, device='cuda:0'), tensor(18, device='cuda:0')),
#  (tensor(17, device='cuda:0'), tensor(19, device='cuda:0')),
#  (tensor(72, device='cuda:0'), tensor(73, device='cuda:0')),
#  (tensor(53, device='cuda:0'), tensor(54, device='cuda:0')),
#  (tensor(77, device='cuda:0'), tensor(81, device='cuda:0')),
#  (tensor(102, device='cuda:0'), tensor(100, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(21, device='cuda:0'), tensor(23, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(59, device='cuda:0'), tensor(60, device='cuda:0')),
#  (tensor(25, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(56, device='cuda:0'), tensor(56, device='cuda:0')),
#  (tensor(102, device='cuda:0'), tensor(102, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(42, device='cuda:0'), tensor(42, device='cuda:0')),
#  (tensor(52, device='cuda:0'), tensor(53, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(135, device='cuda:0'), tensor(148, device='cuda:0')),
#  (tensor(45, device='cuda:0'), tensor(47, device='cuda:0')),
#  (tensor(106, device='cuda:0'), tensor(114, device='cuda:0')),
#  (tensor(32, device='cuda:0'), tensor(34, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(19, device='cuda:0'), tensor(26, device='cuda:0')),
#  (tensor(138, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(31, device='cuda:0')),
#  (tensor(73, device='cuda:0'), tensor(79, device='cuda:0')),
#  (tensor(46, device='cuda:0'), tensor(48, device='cuda:0')),
#  (tensor(25, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(21, device='cuda:0'), tensor(22, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(51, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(53, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(67, device='cuda:0'), tensor(71, device='cuda:0')),
#  (tensor(113, device='cuda:0'), tensor(113, device='cuda:0')),
#  (tensor(77, device='cuda:0'), tensor(78, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(103, device='cuda:0'), tensor(104, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(32, device='cuda:0'), tensor(36, device='cuda:0')),
#  (tensor(45, device='cuda:0'), tensor(49, device='cuda:0')),
#  (tensor(45, device='cuda:0'), tensor(46, device='cuda:0')),
#  (tensor(86, device='cuda:0'), tensor(97, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(146, device='cuda:0'), tensor(148, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(190, device='cuda:0'), tensor(192, device='cuda:0')),
#  (tensor(47, device='cuda:0'), tensor(49, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(215, device='cuda:0'), tensor(216, device='cuda:0')),
#  (tensor(57, device='cuda:0'), tensor(58, device='cuda:0')),
#  (tensor(83, device='cuda:0'), tensor(87, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(97, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(98, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(38, device='cuda:0'), tensor(38, device='cuda:0')),
#  (tensor(155, device='cuda:0'), tensor(156, device='cuda:0')),
#  (tensor(58, device='cuda:0'), tensor(64, device='cuda:0')),
#  (tensor(23, device='cuda:0'), tensor(25, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(46, device='cuda:0')),
#  (tensor(31, device='cuda:0'), tensor(34, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(119, device='cuda:0'), tensor(125, device='cuda:0')),
#  (tensor(13, device='cuda:0'), tensor(13, device='cuda:0')),
#  (tensor(24, device='cuda:0'), tensor(26, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(151, device='cuda:0'), tensor(155, device='cuda:0')),
#  (tensor(119, device='cuda:0'), tensor(104, device='cuda:0')),
#  (tensor(27, device='cuda:0'), tensor(30, device='cuda:0')),
#  (tensor(90, device='cuda:0'), tensor(97, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(89, device='cuda:0'), tensor(89, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(89, device='cuda:0'), tensor(95, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(119, device='cuda:0'), tensor(121, device='cuda:0')),
#  (tensor(18, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(34, device='cuda:0'), tensor(35, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(94, device='cuda:0')),
#  (tensor(30, device='cuda:0'), tensor(30, device='cuda:0')),
#  (tensor(139, device='cuda:0'), tensor(141, device='cuda:0')),
#  (tensor(62, device='cuda:0'), tensor(66, device='cuda:0')),
#  (tensor(14, device='cuda:0'), tensor(16, device='cuda:0')),
#  (tensor(65, device='cuda:0'), tensor(66, device='cuda:0')),
#  (tensor(19, device='cuda:0'), tensor(29, device='cuda:0')),
#  (tensor(186, device='cuda:0'), tensor(186, device='cuda:0')),
#  (tensor(185, device='cuda:0'), tensor(186, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(30, device='cuda:0'), tensor(39, device='cuda:0')),
#  (tensor(64, device='cuda:0'), tensor(67, device='cuda:0')),
#  (tensor(29, device='cuda:0'), tensor(112, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(22, device='cuda:0'), tensor(25, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(73, device='cuda:0'), tensor(73, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(84, device='cuda:0'), tensor(84, device='cuda:0')),
#  (tensor(116, device='cuda:0'), tensor(125, device='cuda:0')),
#  (tensor(73, device='cuda:0'), tensor(74, device='cuda:0')),
#  (tensor(22, device='cuda:0'), tensor(23, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(156, device='cuda:0'), tensor(157, device='cuda:0')),
#  (tensor(14, device='cuda:0'), tensor(17, device='cuda:0')),
#  (tensor(28, device='cuda:0'), tensor(29, device='cuda:0')),
#  (tensor(50, device='cuda:0'), tensor(55, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(88, device='cuda:0')),
#  (tensor(93, device='cuda:0'), tensor(119, device='cuda:0')),
#  (tensor(13, device='cuda:0'), tensor(14, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(99, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(9, device='cuda:0'), tensor(12, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(52, device='cuda:0'), tensor(67, device='cuda:0')),
#  (tensor(101, device='cuda:0'), tensor(102, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(16, device='cuda:0'), tensor(16, device='cuda:0')),
#  (tensor(34, device='cuda:0'), tensor(34, device='cuda:0')),
#  (tensor(52, device='cuda:0'), tensor(82, device='cuda:0')),
#  (tensor(70, device='cuda:0'), tensor(79, device='cuda:0')),
#  (tensor(61, device='cuda:0'), tensor(63, device='cuda:0')),
#  (tensor(39, device='cuda:0'), tensor(40, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(15, device='cuda:0'), tensor(19, device='cuda:0')),
#  (tensor(37, device='cuda:0'), tensor(41, device='cuda:0')),
#  (tensor(30, device='cuda:0'), tensor(30, device='cuda:0')),
#  (tensor(52, device='cuda:0'), tensor(52, device='cuda:0')),
#  (tensor(16, device='cuda:0'), tensor(19, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(54, device='cuda:0')),
#  (tensor(41, device='cuda:0'), tensor(44, device='cuda:0')),
#  (tensor(15, device='cuda:0'), tensor(17, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(15, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(98, device='cuda:0'), tensor(98, device='cuda:0')),
#  (tensor(37, device='cuda:0'), tensor(37, device='cuda:0')),
#  (tensor(115, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(46, device='cuda:0'), tensor(49, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(33, device='cuda:0'), tensor(41, device='cuda:0')),
#  (tensor(158, device='cuda:0'), tensor(160, device='cuda:0')),
#  (tensor(50, device='cuda:0'), tensor(50, device='cuda:0')),
#  (tensor(56, device='cuda:0'), tensor(56, device='cuda:0')),
#  (tensor(105, device='cuda:0'), tensor(109, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(157, device='cuda:0'), tensor(157, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(115, device='cuda:0'), tensor(115, device='cuda:0')),
#  (tensor(88, device='cuda:0'), tensor(88, device='cuda:0')),
#  (tensor(25, device='cuda:0'), tensor(29, device='cuda:0')),
#  (tensor(57, device='cuda:0'), tensor(62, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(64, device='cuda:0'), tensor(65, device='cuda:0')),
#  (tensor(94, device='cuda:0'), tensor(97, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(226, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(107, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(38, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(131, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(38, device='cuda:0'), tensor(38, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(121, device='cuda:0'), tensor(127, device='cuda:0')),
#  (tensor(76, device='cuda:0'), tensor(77, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(134, device='cuda:0'), tensor(142, device='cuda:0')),
#  (tensor(107, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(29, device='cuda:0'), tensor(30, device='cuda:0')),
#  (tensor(15, device='cuda:0'), tensor(19, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(25, device='cuda:0'), tensor(25, device='cuda:0')),
#  (tensor(118, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(33, device='cuda:0'), tensor(34, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(56, device='cuda:0'), tensor(58, device='cuda:0')),
#  (tensor(45, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(154, device='cuda:0')),
#  (tensor(66, device='cuda:0'), tensor(69, device='cuda:0')),
#  (tensor(77, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(97, device='cuda:0'), tensor(97, device='cuda:0')),
#  (tensor(15, device='cuda:0'), tensor(15, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(125, device='cuda:0'), tensor(125, device='cuda:0')),
#  (tensor(66, device='cuda:0'), tensor(69, device='cuda:0')),
#  (tensor(54, device='cuda:0'), tensor(54, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(49, device='cuda:0'), tensor(55, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(55, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(87, device='cuda:0'), tensor(96, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(20, device='cuda:0'), tensor(27, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(103, device='cuda:0')),
#  (tensor(29, device='cuda:0'), tensor(33, device='cuda:0')),
#  (tensor(64, device='cuda:0'), tensor(66, device='cuda:0')),
#  (tensor(45, device='cuda:0'), tensor(61, device='cuda:0')),
#  (tensor(33, device='cuda:0'), tensor(26, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(55, device='cuda:0'), tensor(61, device='cuda:0')),
#  (tensor(124, device='cuda:0'), tensor(140, device='cuda:0')),
#  (tensor(34, device='cuda:0'), tensor(35, device='cuda:0')),
#  (tensor(253, device='cuda:0'), tensor(34, device='cuda:0')),
#  (tensor(99, device='cuda:0'), tensor(100, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(137, device='cuda:0'), tensor(142, device='cuda:0')),
#  (tensor(154, device='cuda:0'), tensor(156, device='cuda:0')),
#  (tensor(99, device='cuda:0'), tensor(102, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(16, device='cuda:0'), tensor(17, device='cuda:0')),
#  (tensor(23, device='cuda:0'), tensor(24, device='cuda:0')),
#  (tensor(32, device='cuda:0'), tensor(34, device='cuda:0')),
#  (tensor(96, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(218, device='cuda:0'), tensor(219, device='cuda:0')),
#  (tensor(93, device='cuda:0'), tensor(93, device='cuda:0')),
#  (tensor(35, device='cuda:0'), tensor(38, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(32, device='cuda:0'), tensor(33, device='cuda:0')),
#  (tensor(161, device='cuda:0'), tensor(163, device='cuda:0')),
#  (tensor(21, device='cuda:0'), tensor(25, device='cuda:0')),
#  (tensor(166, device='cuda:0'), tensor(187, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(66, device='cuda:0'), tensor(72, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(153, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(14, device='cuda:0'), tensor(18, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(113, device='cuda:0'), tensor(134, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(76, device='cuda:0'), tensor(80, device='cuda:0')),
#  (tensor(19, device='cuda:0'), tensor(22, device='cuda:0')),
#  (tensor(14, device='cuda:0'), tensor(15, device='cuda:0')),
#  (tensor(42, device='cuda:0'), tensor(46, device='cuda:0')),
#  (tensor(69, device='cuda:0'), tensor(69, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(90, device='cuda:0'), tensor(93, device='cuda:0')),
#  (tensor(36, device='cuda:0'), tensor(45, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(19, device='cuda:0'), tensor(19, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(69, device='cuda:0'), tensor(71, device='cuda:0')),
#  (tensor(49, device='cuda:0'), tensor(13, device='cuda:0')),
#  (tensor(199, device='cuda:0'), tensor(209, device='cuda:0')),
#  (tensor(21, device='cuda:0'), tensor(22, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(78, device='cuda:0'), tensor(40, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(21, device='cuda:0'), tensor(26, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(80, device='cuda:0'), tensor(82, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(99, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(69, device='cuda:0'), tensor(69, device='cuda:0')),
#  (tensor(124, device='cuda:0'), tensor(126, device='cuda:0')),
#  (tensor(93, device='cuda:0'), tensor(95, device='cuda:0')),
#  (tensor(43, device='cuda:0'), tensor(43, device='cuda:0')),
#  (tensor(39, device='cuda:0'), tensor(40, device='cuda:0')),
#  (tensor(129, device='cuda:0'), tensor(130, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(20, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(215, device='cuda:0'), tensor(215, device='cuda:0')),
#  (tensor(34, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(71, device='cuda:0'), tensor(72, device='cuda:0')),
#  (tensor(42, device='cuda:0'), tensor(46, device='cuda:0')),
#  (tensor(149, device='cuda:0'), tensor(153, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(42, device='cuda:0'), tensor(44, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(107, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(111, device='cuda:0'), tensor(114, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(109, device='cuda:0'), tensor(112, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(29, device='cuda:0'), tensor(35, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(19, device='cuda:0'), tensor(21, device='cuda:0')),
#  (tensor(89, device='cuda:0'), tensor(91, device='cuda:0')),
#  (tensor(71, device='cuda:0'), tensor(72, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(27, device='cuda:0'), tensor(28, device='cuda:0')),
#  (tensor(39, device='cuda:0'), tensor(39, device='cuda:0')),
#  (tensor(82, device='cuda:0'), tensor(83, device='cuda:0')),
#  (tensor(26, device='cuda:0'), tensor(26, device='cuda:0')),
#  (tensor(76, device='cuda:0'), tensor(79, device='cuda:0')),
#  (tensor(35, device='cuda:0'), tensor(66, device='cuda:0')),
#  (tensor(68, device='cuda:0'), tensor(68, device='cuda:0')),
#  (tensor(18, device='cuda:0'), tensor(19, device='cuda:0')),
#  (tensor(140, device='cuda:0'), tensor(143, device='cuda:0')),
#  (tensor(188, device='cuda:0'), tensor(191, device='cuda:0')),
#  (tensor(30, device='cuda:0'), tensor(31, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(62, device='cuda:0'), tensor(63, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(49, device='cuda:0'), tensor(59, device='cuda:0')),
#  (tensor(58, device='cuda:0'), tensor(60, device='cuda:0')),
#  (tensor(22, device='cuda:0'), tensor(23, device='cuda:0')),
#  (tensor(84, device='cuda:0'), tensor(85, device='cuda:0')),
#  (tensor(65, device='cuda:0'), tensor(67, device='cuda:0')),
#  (tensor(42, device='cuda:0'), tensor(43, device='cuda:0')),
#  (tensor(45, device='cuda:0'), tensor(48, device='cuda:0')),
#  (tensor(128, device='cuda:0'), tensor(76, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(97, device='cuda:0'), tensor(97, device='cuda:0')),
#  (tensor(58, device='cuda:0'), tensor(60, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(31, device='cuda:0'), tensor(32, device='cuda:0')),
#  (tensor(106, device='cuda:0'), tensor(126, device='cuda:0')),
#  (tensor(51, device='cuda:0'), tensor(51, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(14, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(49, device='cuda:0'), tensor(73, device='cuda:0')),
#  (tensor(142, device='cuda:0'), tensor(142, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(37, device='cuda:0'), tensor(38, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(111, device='cuda:0'), tensor(113, device='cuda:0')),
#  (tensor(168, device='cuda:0'), tensor(170, device='cuda:0')),
#  (tensor(118, device='cuda:0'), tensor(118, device='cuda:0')),
#  (tensor(71, device='cuda:0'), tensor(72, device='cuda:0')),
#  (tensor(26, device='cuda:0'), tensor(27, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(67, device='cuda:0'), tensor(69, device='cuda:0')),
#  (tensor(23, device='cuda:0'), tensor(23, device='cuda:0')),
#  (tensor(18, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(24, device='cuda:0'), tensor(32, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(16, device='cuda:0'), tensor(17, device='cuda:0')),
#  (tensor(58, device='cuda:0'), tensor(59, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(21, device='cuda:0'), tensor(23, device='cuda:0')),
#  (tensor(60, device='cuda:0'), tensor(60, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(119, device='cuda:0'), tensor(121, device='cuda:0')),
#  (tensor(30, device='cuda:0'), tensor(31, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(28, device='cuda:0'), tensor(29, device='cuda:0')),
#  (tensor(27, device='cuda:0'), tensor(31, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(93, device='cuda:0'), tensor(93, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(234, device='cuda:0'), tensor(239, device='cuda:0')),
#  (tensor(42, device='cuda:0'), tensor(54, device='cuda:0')),
#  (tensor(70, device='cuda:0'), tensor(71, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(141, device='cuda:0'), tensor(145, device='cuda:0')),
#  (tensor(173, device='cuda:0'), tensor(174, device='cuda:0')),
#  (tensor(72, device='cuda:0'), tensor(73, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(104, device='cuda:0')),
#  (tensor(14, device='cuda:0'), tensor(17, device='cuda:0')),
#  (tensor(85, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(14, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(18, device='cuda:0'), tensor(20, device='cuda:0')),
#  (tensor(71, device='cuda:0'), tensor(74, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(13, device='cuda:0'), tensor(16, device='cuda:0')),
#  (tensor(43, device='cuda:0'), tensor(46, device='cuda:0')),
#  (tensor(185, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(58, device='cuda:0'), tensor(62, device='cuda:0')),
#  (tensor(249, device='cuda:0'), tensor(250, device='cuda:0')),
#  (tensor(22, device='cuda:0'), tensor(22, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(44, device='cuda:0'), tensor(47, device='cuda:0')),
#  (tensor(178, device='cuda:0'), tensor(183, device='cuda:0')),
#  (tensor(89, device='cuda:0'), tensor(89, device='cuda:0')),
#  (tensor(18, device='cuda:0'), tensor(20, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(10, device='cuda:0'), tensor(11, device='cuda:0')),
#  (tensor(85, device='cuda:0'), tensor(87, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(17, device='cuda:0'), tensor(18, device='cuda:0')),
#  (tensor(44, device='cuda:0'), tensor(47, device='cuda:0')),
#  (tensor(116, device='cuda:0'), tensor(116, device='cuda:0')),
#  (tensor(78, device='cuda:0'), tensor(82, device='cuda:0')),
#  (tensor(43, device='cuda:0'), tensor(58, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(38, device='cuda:0')),
#  (tensor(28, device='cuda:0'), tensor(30, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(37, device='cuda:0')),
#  (tensor(152, device='cuda:0'), tensor(156, device='cuda:0')),
#  (tensor(121, device='cuda:0'), tensor(121, device='cuda:0')),
#  (tensor(163, device='cuda:0'), tensor(169, device='cuda:0')),
#  (tensor(68, device='cuda:0'), tensor(68, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(27, device='cuda:0'), tensor(31, device='cuda:0')),
#  (tensor(39, device='cuda:0'), tensor(45, device='cuda:0')),
#  (tensor(111, device='cuda:0'), tensor(111, device='cuda:0')),
#  (tensor(13, device='cuda:0'), tensor(17, device='cuda:0')),
#  (tensor(73, device='cuda:0'), tensor(73, device='cuda:0')),
#  (tensor(136, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(68, device='cuda:0'), tensor(68, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(138, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(82, device='cuda:0'), tensor(87, device='cuda:0')),
#  (tensor(51, device='cuda:0'), tensor(54, device='cuda:0')),
#  (tensor(49, device='cuda:0'), tensor(35, device='cuda:0')),
#  (tensor(147, device='cuda:0'), tensor(166, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(65, device='cuda:0'), tensor(69, device='cuda:0')),
#  (tensor(28, device='cuda:0'), tensor(36, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(37, device='cuda:0'), tensor(37, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(39, device='cuda:0'), tensor(40, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(78, device='cuda:0'), tensor(82, device='cuda:0')),
#  (tensor(69, device='cuda:0'), tensor(70, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(152, device='cuda:0'), tensor(152, device='cuda:0')),
#  (tensor(113, device='cuda:0'), tensor(117, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(146, device='cuda:0'), tensor(152, device='cuda:0')),
#  (tensor(91, device='cuda:0'), tensor(99, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(23, device='cuda:0'), tensor(37, device='cuda:0')),
#  (tensor(30, device='cuda:0'), tensor(31, device='cuda:0')),
#  (tensor(93, device='cuda:0'), tensor(94, device='cuda:0')),
#  (tensor(91, device='cuda:0'), tensor(92, device='cuda:0')),
#  (tensor(66, device='cuda:0'), tensor(68, device='cuda:0')),
#  (tensor(158, device='cuda:0'), tensor(159, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(222, device='cuda:0'), tensor(231, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(25, device='cuda:0'), tensor(25, device='cuda:0')),
#  (tensor(77, device='cuda:0'), tensor(80, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(32, device='cuda:0'), tensor(32, device='cuda:0')),
#  (tensor(102, device='cuda:0'), tensor(102, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(13, device='cuda:0'), tensor(15, device='cuda:0')),
#  (tensor(107, device='cuda:0'), tensor(110, device='cuda:0')),
#  (tensor(113, device='cuda:0'), tensor(114, device='cuda:0')),
#  (tensor(89, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(52, device='cuda:0'), tensor(56, device='cuda:0')),
#  (tensor(27, device='cuda:0'), tensor(30, device='cuda:0')),
#  (tensor(35, device='cuda:0'), tensor(35, device='cuda:0')),
#  (tensor(55, device='cuda:0'), tensor(60, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(18, device='cuda:0'), tensor(22, device='cuda:0')),
#  (tensor(10, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(146, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(20, device='cuda:0'), tensor(23, device='cuda:0')),
#  (tensor(28, device='cuda:0'), tensor(21, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(77, device='cuda:0'), tensor(80, device='cuda:0')),
#  (tensor(25, device='cuda:0'), tensor(25, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(143, device='cuda:0'), tensor(146, device='cuda:0')),
#  (tensor(66, device='cuda:0'), tensor(69, device='cuda:0')),
#  (tensor(57, device='cuda:0'), tensor(57, device='cuda:0')),
#  (tensor(18, device='cuda:0'), tensor(20, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(84, device='cuda:0'), tensor(88, device='cuda:0')),
#  (tensor(75, device='cuda:0'), tensor(75, device='cuda:0')),
# ...
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(81, device='cuda:0'), tensor(83, device='cuda:0')),
#  (tensor(39, device='cuda:0'), tensor(41, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(89, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(151, device='cuda:0'), tensor(152, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(106, device='cuda:0'), tensor(106, device='cuda:0')),
#  (tensor(78, device='cuda:0'), tensor(79, device='cuda:0')),
#  (tensor(43, device='cuda:0'), tensor(45, device='cuda:0')),
#  (tensor(66, device='cuda:0'), tensor(72, device='cuda:0')),
#  (tensor(68, device='cuda:0'), tensor(71, device='cuda:0')),
#  (tensor(46, device='cuda:0'), tensor(57, device='cuda:0')),
#  (tensor(52, device='cuda:0'), tensor(52, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(114, device='cuda:0')),
#  (tensor(61, device='cuda:0'), tensor(62, device='cuda:0')),
#  (tensor(62, device='cuda:0'), tensor(64, device='cuda:0')),
#  (tensor(64, device='cuda:0'), tensor(67, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(16, device='cuda:0'), tensor(54, device='cuda:0')),
#  (tensor(205, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(90, device='cuda:0'), tensor(90, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(18, device='cuda:0'), tensor(22, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(9, device='cuda:0'), tensor(19, device='cuda:0')),
#  (tensor(73, device='cuda:0'), tensor(77, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(61, device='cuda:0'), tensor(62, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(149, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(92, device='cuda:0'), tensor(94, device='cuda:0')),
#  (tensor(29, device='cuda:0'), tensor(35, device='cuda:0')),
#  (tensor(89, device='cuda:0'), tensor(90, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(32, device='cuda:0'), tensor(34, device='cuda:0')),
#  (tensor(44, device='cuda:0'), tensor(44, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(87, device='cuda:0'), tensor(89, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(30, device='cuda:0')),
#  (tensor(10, device='cuda:0'), tensor(16, device='cuda:0')),
#  (tensor(118, device='cuda:0'), tensor(120, device='cuda:0')),
#  (tensor(26, device='cuda:0'), tensor(27, device='cuda:0')),
#  (tensor(174, device='cuda:0'), tensor(174, device='cuda:0')),
#  (tensor(29, device='cuda:0'), tensor(30, device='cuda:0')),
#  (tensor(58, device='cuda:0'), tensor(60, device='cuda:0')),
#  (tensor(22, device='cuda:0'), tensor(22, device='cuda:0')),
#  (tensor(11, device='cuda:0'), tensor(12, device='cuda:0')),
#  (tensor(32, device='cuda:0'), tensor(35, device='cuda:0')),
#  (tensor(36, device='cuda:0'), tensor(45, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(128, device='cuda:0'), tensor(136, device='cuda:0')),
#  (tensor(40, device='cuda:0'), tensor(42, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(55, device='cuda:0'), tensor(58, device='cuda:0')),
#  (tensor(68, device='cuda:0'), tensor(68, device='cuda:0')),
#  (tensor(17, device='cuda:0'), tensor(23, device='cuda:0')),
#  (tensor(112, device='cuda:0'), tensor(113, device='cuda:0')),
#  (tensor(66, device='cuda:0'), tensor(78, device='cuda:0')),
#  (tensor(26, device='cuda:0'), tensor(27, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(91, device='cuda:0'), tensor(92, device='cuda:0')),
#  (tensor(60, device='cuda:0'), tensor(61, device='cuda:0')),
#  (tensor(34, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(101, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(27, device='cuda:0'), tensor(27, device='cuda:0')),
#  (tensor(21, device='cuda:0'), tensor(21, device='cuda:0')),
#  (tensor(224, device='cuda:0'), tensor(224, device='cuda:0')),
#  (tensor(33, device='cuda:0'), tensor(34, device='cuda:0')),
#  (tensor(12, device='cuda:0'), tensor(12, device='cuda:0')),
#  (tensor(115, device='cuda:0'), tensor(115, device='cuda:0')),
#  (tensor(23, device='cuda:0'), tensor(24, device='cuda:0')),
#  (tensor(67, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(190, device='cuda:0'), tensor(190, device='cuda:0')),
#  (tensor(28, device='cuda:0'), tensor(33, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(54, device='cuda:0'), tensor(56, device='cuda:0')),
#  (tensor(79, device='cuda:0'), tensor(84, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(33, device='cuda:0'), tensor(34, device='cuda:0')),
#  (tensor(75, device='cuda:0'), tensor(77, device='cuda:0')),
#  (tensor(211, device='cuda:0'), tensor(214, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(93, device='cuda:0'), tensor(98, device='cuda:0')),
#  (tensor(56, device='cuda:0'), tensor(32, device='cuda:0')),
#  (tensor(142, device='cuda:0'), tensor(142, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(19, device='cuda:0'), tensor(19, device='cuda:0')),
#  (tensor(18, device='cuda:0'), tensor(19, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(103, device='cuda:0'), tensor(103, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(106, device='cuda:0'), tensor(111, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(14, device='cuda:0'), tensor(15, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(84, device='cuda:0')),
#  (tensor(14, device='cuda:0'), tensor(15, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(45, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(33, device='cuda:0'), tensor(33, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(155, device='cuda:0'), tensor(157, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(12, device='cuda:0'), tensor(14, device='cuda:0')),
#  (tensor(35, device='cuda:0'), tensor(37, device='cuda:0')),
#  (tensor(58, device='cuda:0'), tensor(59, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(79, device='cuda:0'), tensor(87, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(119, device='cuda:0'), tensor(122, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(65, device='cuda:0'), tensor(65, device='cuda:0')),
#  (tensor(71, device='cuda:0'), tensor(74, device='cuda:0')),
#  (tensor(144, device='cuda:0'), tensor(144, device='cuda:0')),
#  (tensor(123, device='cuda:0'), tensor(125, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(26, device='cuda:0'), tensor(35, device='cuda:0')),
#  (tensor(47, device='cuda:0'), tensor(47, device='cuda:0')),
#  (tensor(100, device='cuda:0'), tensor(101, device='cuda:0')),
#  (tensor(39, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(227, device='cuda:0'), tensor(227, device='cuda:0')),
#  (tensor(103, device='cuda:0'), tensor(111, device='cuda:0')),
#  (tensor(102, device='cuda:0'), tensor(104, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(99, device='cuda:0'), tensor(103, device='cuda:0')),
#  (tensor(77, device='cuda:0'), tensor(80, device='cuda:0')),
#  (tensor(82, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(58, device='cuda:0'), tensor(61, device='cuda:0')),
#  (tensor(46, device='cuda:0'), tensor(47, device='cuda:0')),
#  (tensor(99, device='cuda:0'), tensor(102, device='cuda:0')),
#  (tensor(76, device='cuda:0'), tensor(83, device='cuda:0')),
#  (tensor(59, device='cuda:0'), tensor(59, device='cuda:0')),
#  (tensor(30, device='cuda:0'), tensor(31, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(16, device='cuda:0'), tensor(16, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(146, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(25, device='cuda:0'), tensor(26, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(96, device='cuda:0'), tensor(105, device='cuda:0')),
#  (tensor(64, device='cuda:0'), tensor(70, device='cuda:0')),
#  (tensor(44, device='cuda:0'), tensor(44, device='cuda:0')),
#  (tensor(21, device='cuda:0'), tensor(21, device='cuda:0')),
#  (tensor(62, device='cuda:0'), tensor(63, device='cuda:0')),
#  (tensor(18, device='cuda:0'), tensor(19, device='cuda:0')),
#  (tensor(221, device='cuda:0'), tensor(233, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(53, device='cuda:0'), tensor(57, device='cuda:0')),
#  (tensor(64, device='cuda:0'), tensor(65, device='cuda:0')),
#  (tensor(56, device='cuda:0'), tensor(57, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(26, device='cuda:0'), tensor(26, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(106, device='cuda:0'), tensor(115, device='cuda:0')),
#  (tensor(48, device='cuda:0'), tensor(49, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(136, device='cuda:0'), tensor(136, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(81, device='cuda:0'), tensor(84, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(88, device='cuda:0'), tensor(89, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(49, device='cuda:0'), tensor(71, device='cuda:0')),
#  (tensor(119, device='cuda:0'), tensor(120, device='cuda:0')),
#  (tensor(95, device='cuda:0'), tensor(97, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(12, device='cuda:0'), tensor(14, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(88, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(29, device='cuda:0'), tensor(39, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(191, device='cuda:0'), tensor(203, device='cuda:0')),
#  (tensor(26, device='cuda:0'), tensor(26, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(16, device='cuda:0'), tensor(16, device='cuda:0')),
#  (tensor(80, device='cuda:0'), tensor(80, device='cuda:0')),
#  (tensor(96, device='cuda:0'), tensor(96, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(64, device='cuda:0'), tensor(70, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(38, device='cuda:0'), tensor(43, device='cuda:0')),
#  (tensor(114, device='cuda:0'), tensor(114, device='cuda:0')),
#  (tensor(15, device='cuda:0'), tensor(18, device='cuda:0')),
#  (tensor(123, device='cuda:0'), tensor(126, device='cuda:0')),
#  (tensor(53, device='cuda:0'), tensor(53, device='cuda:0')),
#  (tensor(132, device='cuda:0'), tensor(133, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(106, device='cuda:0'), tensor(114, device='cuda:0')),
#  (tensor(28, device='cuda:0'), tensor(28, device='cuda:0')),
#  (tensor(11, device='cuda:0'), tensor(13, device='cuda:0')),
#  (tensor(20, device='cuda:0'), tensor(20, device='cuda:0')),
#  (tensor(68, device='cuda:0'), tensor(68, device='cuda:0')),
#  (tensor(39, device='cuda:0'), tensor(39, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(117, device='cuda:0')),
#  (tensor(229, device='cuda:0'), tensor(233, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(15, device='cuda:0'), tensor(16, device='cuda:0')),
#  (tensor(64, device='cuda:0'), tensor(69, device='cuda:0')),
#  (tensor(36, device='cuda:0'), tensor(38, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(39, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(24, device='cuda:0'), tensor(26, device='cuda:0')),
#  (tensor(60, device='cuda:0'), tensor(61, device='cuda:0')),
#  (tensor(50, device='cuda:0'), tensor(59, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(77, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(119, device='cuda:0'), tensor(120, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(23, device='cuda:0'), tensor(35, device='cuda:0')),
#  (tensor(32, device='cuda:0'), tensor(33, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(82, device='cuda:0'), tensor(84, device='cuda:0')),
#  (tensor(40, device='cuda:0'), tensor(42, device='cuda:0')),
#  (tensor(84, device='cuda:0'), tensor(84, device='cuda:0')),
#  (tensor(39, device='cuda:0'), tensor(40, device='cuda:0')),
#  (tensor(76, device='cuda:0'), tensor(80, device='cuda:0')),
#  (tensor(136, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(211, device='cuda:0'), tensor(217, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(236, device='cuda:0'), tensor(237, device='cuda:0')),
#  (tensor(133, device='cuda:0'), tensor(137, device='cuda:0')),
#  (tensor(22, device='cuda:0'), tensor(23, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(16, device='cuda:0'), tensor(19, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  (tensor(0, device='cuda:0'), tensor(0, device='cuda:0')),
#  ...]

# %%
torch.save(preds, 'predictions')
torch.save(targs, 'targets')

# %%
assert len(preds) == len(test_features) # ensure complete results after validation for accuracy comparison
# Out:
# (26232, 26232)

# %%
import string
def normalize(tokens):
    """
    Used to normalize tokenized answers for comparison in our accuracy evaluation.
    """
    ans = ' '.join(tokens)
    ans = ''.join(char for char in ans.lower() if char not in set(string.punctuation))
    ans = ' '.join(ans.split())
    return ans

# %% [markdown]
# Now we can iterate over our results and compute our accuracy score.
#
# Accuracy will be computed the following way (may change in the future):
#
# - First, we normalize the predicted answer and the true answer.
# - We then compare and check if the predicted answer is *at least* contained inside of the true answer, resulting in an accuracy point
#
# Future evaluation will be calculated by running the SQuAD test evaluation script available at:
# https://rajpurkar.github.io/SQuAD-explorer/

# %%
# calculate accuracy based on if pred is in answer at all:
count = 0
for i, ((s,e), (st,et)) in enumerate(zip(preds,targs)):
    start_pred = s.item()
    end_pred = e.item()
  
    start_true = st.item()
    end_true = et.item()

    pred_answer = tokenizer.convert_ids_to_tokens(test_features[i]['ids'][start_pred:end_pred+1])
    true_answer = tokenizer.convert_ids_to_tokens(test_features[i]['ids'][start_true:end_true+1])

    if normalize(pred_answer) in normalize(true_answer):
    count += 1
    
    # elif normalize(true_answer)in normalize(pred_answer):
    #   count += 1

print('Accuracy Score: {}'.format(count/ len(test_features)))
# Out:
# Accuracy Score: 0.46187862153095455

# %% [markdown]
# As you can see, when we evaluate accuracy using the *predicted answer in true answer* approach, we get **~46%** accuracy. When we stretch acceptance criteria a little further (seen in the commented out code above), we can get upwards of **~77%** accuracy.

# %% [markdown]
# ### Test on a Random Question
#
# We will use a sample input question about BERT itself, found as an example [here](https://mccormickml.com/2020/03/10/question-answering-with-a-fine-tuned-BERT/#bert-input-format).

# %%
# Using an example input question seen at: https://mccormickml.com/2020/03/10/question-answering-with-a-fine-tuned-BERT/#bert-input-format
question = "How many parameters does BERT-large have?"
answer_text = "BERT-large is really big... it has 24-layers and an embedding size of 1,024, for a total of 340M parameters! Altogether it is 1.34GB, so expect it to take a couple minutes to download to your Colab instance."

input_ids = tokenizer.encode(question, answer_text)
tokens = tokenizer.convert_ids_to_tokens(input_ids)

sep_index = input_ids.index(tokenizer.sep_token_id)
num_seg_a = sep_index + 1

num_seg_b = len(input_ids) - num_seg_a

segment_ids = [0]*num_seg_a + [1]*num_seg_b

assert len(segment_ids) == len(input_ids)

result = model(torch.tensor([input_ids]).to(device), # The tokens representing our input text.
                                 token_type_ids=torch.tensor([segment_ids]).to(device)) # The segment IDs to differentiate question from answer_text

# Find the tokens with the highest `start` and `end` scores.
answer_start = torch.argmax(result[0])
answer_end = torch.argmax(result[1])

# Combine the tokens in the answer and print it out.
answer = ' '.join(tokens[answer_start:answer_end+1])

print('Answer: "' + answer + '"')
# Out:
# Answer: "340 ##m"

# %% [markdown]
# It appears our fine-tuned BERT model answered **correctly**.
